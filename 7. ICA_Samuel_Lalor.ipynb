# %% [markdown]
# Sources in this ICA<br>
# Data Source: basketball reference (https://www.basketball-reference.com)<br>

# %% [markdown]
# Let's first import pandas and data.

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
df = pd.read_excel('nba_2021_2023.xlsx')

# %% [markdown]
# It is NBA player data in 20-21, 21-22, 22-23 seasons

# %%
df
# Out:
#        Rk             Player Pos  Age   Tm   G  GS    MP   FG   FGA    FG%  \
# 0       1   Precious Achiuwa  PF   21  MIA  61   4   737  124   228  0.544
# 1       2       Jaylen Adams  PG   24  MIL   7   0    18    1     8  0.125
# 2       3       Steven Adams   C   27  NOP  58  58  1605  189   308  0.614
# 3       4        Bam Adebayo   C   23  MIA  64  64  2143  456   800  0.570
# 4       5  LaMarcus Aldridge   C   35  SAS  21  18   544  115   248  0.464
# ...   ...                ...  ..  ...  ...  ..  ..   ...  ...   ...    ...
# 1945  535     Thaddeus Young  PF   34  TOR  54   9   795  108   198  0.545
# 1946  536         Trae Young  PG   24  ATL  73  73  2541  597  1390  0.429
# 1947  537     Omer Yurtseven   C   24  MIA   9   0    83   16    27  0.593
# 1948  538        Cody Zeller   C   30  MIA  15   2   217   37    59  0.627
# 1949  539        Ivica Zubac   C   25  LAC  76  76  2170  326   514  0.634
#
# ...

# %% [markdown]
# ### Let's dive into pivot_table()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# It creates a new table grouping columns
# Syntax
df.pivot_table(values = ..., index = ..., columns = ..., aggfunc = ..., fill_value = ...)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 3
#       1 # It creates a new table grouping columns
#       2 # Syntax
# ----> 3 df.pivot_table(values = ..., index = ..., columns = ..., aggfunc = ..., fill_value = ...)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:8579, in DataFrame.pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#    8562 @Substitution("")
#    8563 @Appender(_shared_docs["pivot_table"])
#    8564 def pivot_table(
#    (...)
#    8575     sort: bool = True,
#    8576 ) -> DataFrame:
#    8577     from pandas.core.reshape.pivot import pivot_table
# -> 8579     return pivot_table(
#    8580         self,
#    8581         values=values,
#    8582         index=index,
#    8583         columns=columns,
#    8584         aggfunc=aggfunc,
# ...

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined

# %% [markdown]
# ### 1. Average Age

# %% [markdown]
# <b> Get a pivot table that shows the average age of EACH team for the three seasons (from 20/21 to 22/23)</b><br>
# Hint: Use Age and Tm columns

# %%
df
# Out:
#        Rk             Player Pos  Age   Tm   G  GS    MP   FG   FGA    FG%  \
# 0       1   Precious Achiuwa  PF   21  MIA  61   4   737  124   228  0.544
# 1       2       Jaylen Adams  PG   24  MIL   7   0    18    1     8  0.125
# 2       3       Steven Adams   C   27  NOP  58  58  1605  189   308  0.614
# 3       4        Bam Adebayo   C   23  MIA  64  64  2143  456   800  0.570
# 4       5  LaMarcus Aldridge   C   35  SAS  21  18   544  115   248  0.464
# ...   ...                ...  ..  ...  ...  ..  ..   ...  ...   ...    ...
# 1945  535     Thaddeus Young  PF   34  TOR  54   9   795  108   198  0.545
# 1946  536         Trae Young  PG   24  ATL  73  73  2541  597  1390  0.429
# 1947  537     Omer Yurtseven   C   24  MIA   9   0    83   16    27  0.593
# 1948  538        Cody Zeller   C   30  MIA  15   2   217   37    59  0.627
# 1949  539        Ivica Zubac   C   25  LAC  76  76  2170  326   514  0.634
#
# ...

# %% [markdown]
# <b> Get a pivot table that shows the average age of EACH team in EACH season (from 20/21 to 22/23)</b><br>
# Hint: Use Age, Tm, and Season columns

# %%
# Answer
df.pivot_table(values='Age', index='Tm', columns = 'Season')
# Out:
# Season       2021       2022       2023
# Tm
# ATL     25.666667  25.958333  24.700000
# BOS     25.000000  26.500000  26.777778
# BRK     27.000000  28.541667  27.000000
# CHI     25.500000  25.272727  26.777778
# CHO     24.294118  24.947368  24.578947
# CLE     25.520000  26.076923  27.111111
# DAL     26.578947  26.592593  28.086957
# DEN     25.500000  26.454545  26.722222
# DET     24.714286  24.111111  24.272727
# GSW     25.500000  27.411765  26.333333
# HOU     25.966667  24.526316  23.666667
# IND     25.300000  25.892857  25.500000
# LAC     27.600000  26.826087  28.333333
# LAL     28.000000  29.080000  26.416667
# MEM     24.277778  23.782609  24.210526
# MIA     28.142857  27.500000  27.750000
# MIL     27.136364  27.344828  29.523810
# MIN     23.437500  24.555556  25.500000
# NOP     25.571429  25.727273  25.705882
# NYK     25.210526  25.695652  25.000000
# OKC     23.863636  23.807692  23.263158
# ORL     24.892857  24.500000  23.900000
# ...

# %%
test.loc['ATL', 2021]
# Out:
# 25.666666666666668

# %%
df.pivot_table(values = ..., index = ..., columns = ...)

# %% [markdown]
# ### 2. Total Field Goals

# %% [markdown]
# <b> Get a pivot table that shows each team's total of field goals for the three seasons (from 20/21 to 22/23) </b><br>
# Hint: Use FG and Tm columns and aggfunc="sum"<br>

# %%
# Answer
df.pivot_table(values = 'FG', index = 'Tm', aggfunc = 'sum')
# Out:
#         FG
# Tm
# ATL   9996
# BOS   9786
# BRK   9947
# CHI   9945
# CHO   9768
# CLE   9441
# DAL   9463
# DEN  10104
# DET   9156
# GSW   9834
# HOU   9384
# IND   9957
# LAC   9664
# LAL   9856
# MEM  10241
# MIA   9285
# MIL  10154
# MIN   9858
# NOP   9801
# NYK   9371
# OKC   9469
# ORL   9216
# PHI   9558
# PHO  10152
# POR   9451
# SAC   9961
# SAS  10093
# TOR   9625
# UTA   9783
# WAS   9891

# %%
df.pivot_table(values='FG', index = 'Tm', aggfunc = 'sum', columns = 'Season')
# Out:
# Season  2021  2022  2023
# Tm
# ATL     2937  3401  3658
# BOS     2985  3341  3460
# BRK     3106  3442  3399
# CHI     3035  3422  3488
# CHO     2875  3508  3385
# CLE     2778  3255  3408
# DAL     2958  3222  3283
# DEN     3114  3416  3574
# DET     2783  3129  3244
# GSW     2973  3323  3538
# HOU     2826  3229  3329
# IND     3115  3398  3444
# LAC     3009  3285  3370
# LAL     2925  3415  3516
# MEM     3085  3571  3585
# MIA     2824  3246  3215
# MIL     3221  3429  3504
# MIN     2932  3411  3515
# NOP     3060  3294  3447
# NYK     2839  3088  3444
# OKC     2795  3141  3533
# ORL     2754  3139  3323
# PHI     2981  3230  3347
# PHO     3118  3581  3453
# POR     2973  3161  3317
# SAC     3067  3321  3573
# SAS     3014  3546  3533
# TOR     2859  3332  3434
# UTA     2971  3327  3485
# WAS     3108  3327  3456

# %% [markdown]
# <b> Get a pivot table that shows each team's total of field goals in EACH season </b><br>
# Pass 'Season' to columns for this question. (pass 'Tm' to index)<br>
# Hint: Use FG, Tm, and Season columns and aggfunc="sum"<br>

# %%
# Answer
df.pivot_table(values='FG', index = 'Tm', aggfunc = 'sum', columns = 'Season')
# Out:
# Season  2021  2022  2023
# Tm
# ATL     2937  3401  3658
# BOS     2985  3341  3460
# BRK     3106  3442  3399
# CHI     3035  3422  3488
# CHO     2875  3508  3385
# CLE     2778  3255  3408
# DAL     2958  3222  3283
# DEN     3114  3416  3574
# DET     2783  3129  3244
# GSW     2973  3323  3538
# HOU     2826  3229  3329
# IND     3115  3398  3444
# LAC     3009  3285  3370
# LAL     2925  3415  3516
# MEM     3085  3571  3585
# MIA     2824  3246  3215
# MIL     3221  3429  3504
# MIN     2932  3411  3515
# NOP     3060  3294  3447
# NYK     2839  3088  3444
# OKC     2795  3141  3533
# ORL     2754  3139  3323
# PHI     2981  3230  3347
# PHO     3118  3581  3453
# POR     2973  3161  3317
# SAC     3067  3321  3573
# SAS     3014  3546  3533
# TOR     2859  3332  3434
# UTA     2971  3327  3485
# WAS     3108  3327  3456

# %% [markdown]
# <b> Store the pivot table above to df_team_fg</b>

# %%
# Answer
df_team_fg = df.pivot_table(values='FG', index = 'Tm', aggfunc = 'sum', columns = 'Season')
df_team_fg
# Out:
# Season  2021  2022  2023
# Tm
# ATL     2937  3401  3658
# BOS     2985  3341  3460
# BRK     3106  3442  3399
# CHI     3035  3422  3488
# CHO     2875  3508  3385
# CLE     2778  3255  3408
# DAL     2958  3222  3283
# DEN     3114  3416  3574
# DET     2783  3129  3244
# GSW     2973  3323  3538
# HOU     2826  3229  3329
# IND     3115  3398  3444
# LAC     3009  3285  3370
# LAL     2925  3415  3516
# MEM     3085  3571  3585
# MIA     2824  3246  3215
# MIL     3221  3429  3504
# MIN     2932  3411  3515
# NOP     3060  3294  3447
# NYK     2839  3088  3444
# OKC     2795  3141  3533
# ORL     2754  3139  3323
# PHI     2981  3230  3347
# PHO     3118  3581  3453
# POR     2973  3161  3317
# SAC     3067  3321  3573
# SAS     3014  3546  3533
# TOR     2859  3332  3434
# UTA     2971  3327  3485
# WAS     3108  3327  3456

# %% [markdown]
# Print df_team_fg

# %% [markdown]
# The resulting dataframe is the same as the ones we have seen.<br>
# The top row in bold is a column label.<br>
# The leftmost columnn in bold is a row label.

# %% [markdown]
# ![image.png](attachment:95248696-a583-4cb0-a393-979007bdc4c8.png)

# %% [markdown]
# <b> Print each season(column) in df_team_fg </b>

# %%
# Answer - 2021 season
df_team_fg[2021]
# Out:
# Tm
# ATL    2937
# BOS    2985
# BRK    3106
# CHI    3035
# CHO    2875
# CLE    2778
# DAL    2958
# DEN    3114
# DET    2783
# GSW    2973
# HOU    2826
# IND    3115
# LAC    3009
# LAL    2925
# MEM    3085
# MIA    2824
# MIL    3221
# MIN    2932
# NOP    3060
# NYK    2839
# OKC    2795
# ORL    2754
# PHI    2981
# PHO    3118
# POR    2973
# SAC    3067
# SAS    3014
# TOR    2859
# UTA    2971
# WAS    3108
# Name: 2021, dtype: int64

# %%
# Answer - 2022 season
df_team_fg[2022]
# Out:
# Tm
# ATL    3401
# BOS    3341
# BRK    3442
# CHI    3422
# CHO    3508
# CLE    3255
# DAL    3222
# DEN    3416
# DET    3129
# GSW    3323
# HOU    3229
# IND    3398
# LAC    3285
# LAL    3415
# MEM    3571
# MIA    3246
# MIL    3429
# MIN    3411
# NOP    3294
# NYK    3088
# OKC    3141
# ORL    3139
# PHI    3230
# PHO    3581
# POR    3161
# SAC    3321
# SAS    3546
# TOR    3332
# UTA    3327
# WAS    3327
# Name: 2022, dtype: int64

# %%
# Answer - 2023 season
df_team_fg[2023]
# Out:
# Tm
# ATL    3658
# BOS    3460
# BRK    3399
# CHI    3488
# CHO    3385
# CLE    3408
# DAL    3283
# DEN    3574
# DET    3244
# GSW    3538
# HOU    3329
# IND    3444
# LAC    3370
# LAL    3516
# MEM    3585
# MIA    3215
# MIL    3504
# MIN    3515
# NOP    3447
# NYK    3444
# OKC    3533
# ORL    3323
# PHI    3347
# PHO    3453
# POR    3317
# SAC    3573
# SAS    3533
# TOR    3434
# UTA    3485
# WAS    3456
# Name: 2023, dtype: int64

# %% [markdown]
# <b>Let's sort df_team_fg based on 2021 in a descending order.<br>
# Use sort_values(2021, ascending=False) function to df_team_fg. What happens?</b>

# %%
sorted_df = df_team_fg.sort_values(2021, ascending=False)
sorted_df
# Out:
# Season  2021  2022  2023
# Tm
# MIL     3221  3429  3504
# PHO     3118  3581  3453
# IND     3115  3398  3444
# DEN     3114  3416  3574
# WAS     3108  3327  3456
# BRK     3106  3442  3399
# MEM     3085  3571  3585
# SAC     3067  3321  3573
# NOP     3060  3294  3447
# CHI     3035  3422  3488
# SAS     3014  3546  3533
# LAC     3009  3285  3370
# BOS     2985  3341  3460
# PHI     2981  3230  3347
# POR     2973  3161  3317
# GSW     2973  3323  3538
# UTA     2971  3327  3485
# DAL     2958  3222  3283
# ATL     2937  3401  3658
# MIN     2932  3411  3515
# LAL     2925  3415  3516
# CHO     2875  3508  3385
# TOR     2859  3332  3434
# NYK     2839  3088  3444
# HOU     2826  3229  3329
# MIA     2824  3246  3215
# OKC     2795  3141  3533
# DET     2783  3129  3244
# CLE     2778  3255  3408
# ORL     2754  3139  3323

# %% [markdown]
# * Which team made the most field goals in the 2020-2021 season?

# %%
# Answer
Milwaukee
