# %% [markdown]
# ## Before you close this Jupyter Notebook,

# %% [markdown]
# 1. Go to File > Save Notebook.
# 2. Check if the last checkpoint (next to the file name on the top) is within the last minute.
# 3. Do not close this file. With it opened, upload the file on Canvas.
# 4. Download the uploaded file on Canvas and open it.
# 5. If the file is up to date, you may close all the Jupyter Notebooks.
# 6. Raise your hand and ask for help if you need.

# %% [markdown]
# ## After leaving this classroom, you no longer have a chance for submission.
# ## On Canvas, you will have only one chance to upload your file.
# ## If you submitted a wrong file, let the instructor know and email your file to him before leaving the classroom.
# youngjin.kwon@wsu.edu

# %% [markdown]
# ## A List of Functions and Methods

# %% [markdown]
# * <b>string methods</b>
#     * string.split(...)
#     * string.replace(... , ...)
#     * string.upper()
#     * string.lower()
#     * string.startswith(...)
# <br>
# * <b>list methods</b>
#     * list.append(...)
#     * list.extend(...)
#     * list.remove(...)
#     * list.pop(...)
#     * list.sort(...)
# <br>
# * <b>functions</b>
#     * print(...)
#     * input(...)
#     * len(...)
#     * max(...)
#     * min(...)
#     * int(...)
#     * float(...)
#     * str(...)
#     * type(...)

# %% [markdown]
# +: summation<br>
# -: subtraction<br>
# *: multiplication<br>
# /: division<br>
# %: remainder<br>
#
# == : is equal to<br>
# != : is not equal to<br>
# \> : greater than<br>
# \>= : greater than/equal to<br>
# \< : smaller than<br>
# \<= : smaller than/equal to<br>

# %% [markdown]
# ------------------------------------------------------------------------

# %% [markdown]
# ## Quiz 3

# %% [markdown]
# 1. Explain why the following combinations of True and False returns True.

# %%
not True or False and False or not False
# Out:
# True

# %%
# Answer
#On the left side of the 'and' 'not true or false' evaluates to false or false. and on the left side of the 'and'
#it says false or true, so this means one side evaluates to true and the other to false which in turn means true.

# %% [markdown]
# ------------------------------------------------------------------------

# %% [markdown]
# 2. Write a condition that can come in between if and : <br>
#     (i.e., a condition that will return either True or False)<br>
#
#     Note 1: Your answer doesn't need if and colon(:). Simply provide a condition that evaluates the following questions<br>
#     Note 2: Since we do not define variables in the questions below, your answer will spit out an error.

# %% [markdown]
# (1) a variable, x, is one of the keys in dictionary, dict_1

# %%
# Answer

x in dict_1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 4
#       1 # Answer
#       2 dict_1 = ['1','2','3']
# ----> 4 x in dict_1
#
# NameError: name 'x' is not defined

# %% [markdown]
# (2) a variable, x, is greater than 12 or smaller than or equal to 4.

# %%
# Answer

x > 12 or x <= 4

# %% [markdown]
# ------------------------------------------------------------------------

# %% [markdown]
# ![image.png](attachment:9cac7dd8-9752-4d84-b522-d417f1050e17.png)

# %%
num = int(input("Enter a number"))

if 0 < num < 1:
    print('if statement triggered')
elif 1 < num < 13:
    print('elif statement triggered')
else:
    print('else statement triggered')

# %%
# Answer

# if the input 'num' does not fit the conditions of either the if or elif statement then the else statement will be executed.

# %% [markdown]
# ------------------------------------------------------------------------

# %% [markdown]
# ![image.png](attachment:670e789d-17b1-4927-9c23-e565c36d3212.png)

# %%
# Do not modify this cell; answer in the cell below
fruits = ["apple", "banana", "cherry"]

if _______________:
    print("Banana is in the list")

# %%
# Answer
fruits = ["apple", "banana", "cherry"]

if 'banana' in fruits:
    print("Banana is in the list")
# Out:
# Banana is in the list

# %% [markdown]
# ------------------------------------------------------------------------

# %% [markdown]
# ![image.png](attachment:bf2229d8-16fe-44ae-b01d-53294db56070.png)

# %%
# Do not modify this cell; answer in the cell below
if _____________________:
    print("Condition met")
else:
    print("Condition not met")

# %%
# Answer
if age > 10 and weight < 150:
    print("Condition met")
else:
    print("Condition not met")
# Out:
# Condition met

# %% [markdown]
# ------------------------------------------------------------------------

# %% [markdown]
# ![image.png](attachment:a6a88f5b-5ce9-4d57-9870-1d8858fc4c78.png)

# %%
# Assume that users enter only a number.
income = int(input('What is your income?'))
# Out:
# What is your income?8800

# %%
# Answer
income = int(income)
if income <= 96000 and income >= 44001:
    tax =  11000 * 0.1 + (44000-11000) * 0.12 + (income-44000) * 0.22
elif income <= 44000 and income >= 11001:
    tax = 11000 * 0.1 + (income-11000) * 0.12
elif income <= 11000:
    tax = income * 0.1
print(tax)
# Out:
# 880.0

# %% [markdown]
# ------------------------------------------------------------------------

# %% [markdown]
# 7. Answer the following questions using the d_game dictionary

# %%
d_game = {'name': 'Palworld',
    'release_date': 'Jan 18, 2024',
     'reviews': {'avg_rating': 4.0, 'no_review': 226635},
     'genre': ['multi', 'openworld', 'survival'],
     'price': 29.99
    }

# %% [markdown]
# ![image.png](attachment:c79942e7-5bfb-4e40-8fca-f9dcc981950c.png)

# %%
# Answer

if d_game['price'] < 40 and d_game['reviews']['avg_rating'] > 3.5:
    print('recommend it')
else:
    print('do not buy it')
# Out:
# recommend it

# %% [markdown]
# ![image.png](attachment:7dc8be70-21c7-4beb-996e-da9d675f99db.png)

# %%
# Answer

fav_g = input('Enter your favorite genre of game: ')

if fav_g == d_game['genre'][0] or fav_g == d_game['genre'][1] or fav_g == d_game['genre'][2]:
    print('This game is for you!')
else:
    print('This game is not for you.')
# Out:
# Enter your favorite genre of game: open
# This game is not for you.

# %% [markdown]
# ------------------------------------------------------------------------

# %% [markdown]
# ![image.png](attachment:b11ad98f-b4da-4c20-bb69-319b302c5df7.png)

# %% [markdown]
# ![image.png](attachment:0eebaa79-b81c-493b-8594-b3385c58e775.png)

# %%
# Do not modify this code
# Assume that a user will always enter a number to this input() function
# (i.e., You don't need to use .isdigit() method)
leap_year = int(input('Enter a year'))
# Out:
# Enter a year1900

# %%
# Answer
if leap_year % 4 == 0:
    print(f'{leap_year} is a leap year.')
elif leap_year % 400 == 0:
    print(f'{leap_year} is a leap year')
elif leap_year % 100 ==0:
    print(f'{leap_year} is not a leap year.')
else:
    print(f'{leap_year} is not a leap year.')
# Out:
# 1900 is a leap year.
